# %%
import pandas as pd
df = pd.read_csv("D:/Python/achieves/2008.csv", nrows=1e6)

# %%
dfduplicate =pd.concat([df,df])

# %%
dfduplicate = dfduplicate.sample(frac=1)

# %%
dfclean = dfduplicate.drop_duplicates()

# %%
len(dfclean) == len(df)
# Out:
# False

# %%
len(dfclean)
# Out:
# 999996

# %%
len(df)
# Out:
# 1000000

# %%
dfclean.drop_duplicates(subset = "DayofMonth")
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 260873  2008      1           4          5   1907.0        1910   2133.0
# 608253  2008      2           3          7   1354.0        1335   1546.0
# 179949  2008      1           7          1   1011.0         800   1210.0
# 986057  2008      2          21          4   1158.0        1130   1407.0
# 842680  2008      2          13          3    607.0         600    901.0
# 227655  2008      1           8          2    846.0         839   1343.0
# 713666  2008      2          26          2   1651.0        1650   1911.0
# 164155  2008      1          23          3   1850.0        1855   2008.0
# 669752  2008      2          22          5    636.0         635    943.0
# 655203  2008      2          18          1   1936.0        1935   1935.0
# 71544   2008      1          25          5   1202.0        1210   1423.0
# 46525   2008      1          17          4   1804.0        1650   2051.0
# 599302  2008      1          10          4    759.0         800   1005.0
# 135022  2008      1           9          3   2220.0        2220   2315.0
# 252937  2008      1          11          5   1140.0        1140   1342.0
# 145835  2008      1          24          4    710.0         715    755.0
# 159437  2008      1          15          2   1410.0        1315   1540.0
# 531115  2008      1          29          2    705.0         715    740.0
# 892704  2008      2          16          6   1000.0        1005   1323.0
# 158857  2008      1          14          1   1207.0        1207   1333.0
# 616363  2008      2           6          3    803.0         805    853.0
# 712724  2008      2          20          3   1519.0        1500   1619.0
# 825871  2008      2          12          2   1915.0        1819   2242.0
# 215821  2008      1          30          3   2121.0        2131   2213.0
# 294497  2008      1          31          4   1907.0        1900   2025.0
# 905814  2008      2          27          3   2243.0        2250    739.0
# 112011  2008      1          19          6    905.0         855   1120.0
# 519976  2008      1           1          2   1024.0         940   1236.0
# 809441  2008      2          28          4   1406.0        1408   1436.0
# 176236  2008      1           5          6   2037.0        1925   2154.0
# 377126  2008      1           2          3   1645.0        1640   1714.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 260873        2114            US       1502  ...   19.0     19.0          0
# 608253        1535            WN       1536  ...    4.0      9.0          0
# 179949         956            OO       5861  ...    5.0     20.0          0
# 986057        1400            MQ       4048  ...    8.0     10.0          0
# 842680         909            UA       1442  ...    5.0     10.0          0
# 227655        1352            UA        348  ...    5.0      8.0          0
# 713666        1905            XE       2798  ...    6.0     25.0          0
# 164155        2044            OH       5478  ...    8.0     35.0          0
# 669752         945            WN        362  ...    2.0     26.0          0
# 655203        1940            WN        890  ...    5.0      7.0          0
# 71544         1425            WN        281  ...    4.0     11.0          0
# 46525         1915            WN       3234  ...   11.0     12.0          0
# 599302        1009            DL        619  ...    9.0     12.0          0
# 135022        2341            YV       2681  ...    3.0     12.0          0
# 252937        1347            UA       1508  ...    6.0     17.0          0
# 145835         806            YV       2639  ...   11.0     11.0          0
# 159437        1459            OH       5645  ...    3.0     18.0          0
# 531115         752            AQ        201  ...    5.0      9.0          0
# 892704        1335            DL       1458  ...    8.0     18.0          0
# 158857        1346            OH       5627  ...    8.0      6.0          0
# 616363         900            WN       1452  ...    3.0     11.0          0
# 712724        1607            XE       2040  ...    4.0     26.0          0
# 825871        2141            UA        514  ...    5.0     12.0          0
# 215821        2234            OO       5775  ...    4.0     12.0          0
# 294497        2014            US       2184  ...    6.0     25.0          0
# 905814         750            DL        550  ...    7.0     10.0          0
# 112011        1114            XE       3128  ...    6.0     15.0          0
# 519976        1205            AA       1909  ...   10.0     19.0          0
# 809441        1448            OO       6747  ...    3.0     11.0          0
# 176236        2055            OO       4069  ...    6.0     14.0          0
# 377126        1709            HA        190  ...    5.0      5.0          0
#
#         CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 260873               NaN         0           0.0          0.0     19.0
# 608253               NaN         0           NaN          NaN      NaN
# 179949               NaN         0           0.0        134.0      0.0
# 986057               NaN         0           NaN          NaN      NaN
# 842680               NaN         0           NaN          NaN      NaN
# 227655               NaN         0           NaN          NaN      NaN
# 713666               NaN         0           NaN          NaN      NaN
# 164155               NaN         0           NaN          NaN      NaN
# 669752               NaN         0           NaN          NaN      NaN
# 655203               NaN         0           NaN          NaN      NaN
# 71544                NaN         0           NaN          NaN      NaN
# 46525                NaN         0           0.0          0.0     84.0
# 599302               NaN         0           NaN          NaN      NaN
# 135022               NaN         0           NaN          NaN      NaN
# 252937               NaN         0           NaN          NaN      NaN
# 145835               NaN         0           NaN          NaN      NaN
# 159437               NaN         0          41.0          0.0      0.0
# 531115               NaN         0           NaN          NaN      NaN
# 892704               NaN         0           NaN          NaN      NaN
# 158857               NaN         0           NaN          NaN      NaN
# 616363               NaN         0           NaN          NaN      NaN
# 712724               NaN         0           NaN          NaN      NaN
# 825871               NaN         0           0.0          0.0      5.0
# 215821               NaN         0           NaN          NaN      NaN
# 294497               NaN         0           NaN          NaN      NaN
# 905814               NaN         0           NaN          NaN      NaN
# 112011               NaN         0           NaN          NaN      NaN
# 519976               NaN         0           0.0          0.0     31.0
# 809441               NaN         0           NaN          NaN      NaN
# 176236               NaN         0           0.0          0.0      0.0
# 377126               NaN         0           NaN          NaN      NaN
#
#         SecurityDelay  LateAircraftDelay
# 260873            0.0                0.0
# 608253            NaN                NaN
# 179949            0.0                0.0
# 986057            NaN                NaN
# 842680            NaN                NaN
# 227655            NaN                NaN
# 713666            NaN                NaN
# 164155            NaN                NaN
# 669752            NaN                NaN
# 655203            NaN                NaN
# 71544             NaN                NaN
# 46525             0.0               12.0
# 599302            NaN                NaN
# 135022            NaN                NaN
# 252937            NaN                NaN
# 145835            NaN                NaN
# 159437            0.0                0.0
# 531115            NaN                NaN
# 892704            NaN                NaN
# 158857            NaN                NaN
# 616363            NaN                NaN
# 712724            NaN                NaN
# 825871            0.0               56.0
# 215821            NaN                NaN
# 294497            NaN                NaN
# 905814            NaN                NaN
# 112011            NaN                NaN
# 519976            0.0                0.0
# 809441            NaN                NaN
# 176236            0.0               59.0
# 377126            NaN                NaN
#
# [31 rows x 29 columns]

# %%
df.dropna(subset=["CancellationCode"])
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178     2008      1           3          4      NaN         700      NaN
# 373     2008      1           3          4      NaN        1100      NaN
# 399     2008      1           3          4      NaN         905      NaN
# 401     2008      1           3          4      NaN        1620      NaN
# 415     2008      1           3          4      NaN        1930      NaN
# ...      ...    ...         ...        ...      ...         ...      ...
# 999913  2008      2          11          1      NaN         855      NaN
# 999919  2008      2          17          7      NaN         855      NaN
# 999961  2008      2          17          7      NaN        1445      NaN
# 999971  2008      2          22          5      NaN        1235      NaN
# 999999  2008      2          17          7      NaN        1655      NaN
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 178            830            WN        126  ...    NaN      NaN          1
# 373           1215            WN       1146  ...    NaN      NaN          1
# 399           1025            WN        469  ...    NaN      NaN          1
# 401           1740            WN        618  ...    NaN      NaN          1
# 415           2035            WN       2528  ...    NaN      NaN          1
# ...            ...           ...        ...  ...    ...      ...        ...
# 999913        1210            MQ       4693  ...    NaN      NaN          1
# 999919        1210            MQ       4693  ...    NaN      NaN          1
# 999961        1630            MQ       4694  ...    NaN      NaN          1
# 999971        1415            MQ       4694  ...    NaN      NaN          1
# 999999        2005            MQ       4695  ...    NaN      NaN          1
#
#         CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 178                    A         0           NaN          NaN      NaN
# 373                    A         0           NaN          NaN      NaN
# 399                    A         0           NaN          NaN      NaN
# 401                    C         0           NaN          NaN      NaN
# 415                    A         0           NaN          NaN      NaN
# ...                  ...       ...           ...          ...      ...
# 999913                 A         0           NaN          NaN      NaN
# 999919                 B         0           NaN          NaN      NaN
# 999961                 B         0           NaN          NaN      NaN
# 999971                 B         0           NaN          NaN      NaN
# 999999                 B         0           NaN          NaN      NaN
#
#         SecurityDelay  LateAircraftDelay
# 178               NaN                NaN
# 373               NaN                NaN
# 399               NaN                NaN
# 401               NaN                NaN
# 415               NaN                NaN
# ...               ...                ...
# 999913            NaN                NaN
# 999919            NaN                NaN
# 999961            NaN                NaN
# 999971            NaN                NaN
# 999999            NaN                NaN
#
# [32133 rows x 29 columns]
