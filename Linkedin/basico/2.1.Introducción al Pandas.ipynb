# %%
import pandas as pd

# %%
df = pd.read_csv("D:/Python/Jupyter/base_datos_2008.csv", nrows=10000)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
# 7  2008      1           3          4   1039.0        1040   1132.0
# 8  2008      1           3          4    617.0         615    652.0
# 9  2008      1           3          4   1620.0        1620   1639.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# ...

# %%
df.tail()
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 9995  2008      1           6          7   2000.0        1955   2121.0
# 9996  2008      1           6          7   1624.0        1620   1742.0
# 9997  2008      1           6          7   1946.0        1805   2059.0
# 9998  2008      1           6          7   1549.0        1430   1706.0
# 9999  2008      1           6          7   1050.0        1050   1211.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 9995        2115            WN        593  ...    5.0     13.0          0
# 9996        1740            WN        618  ...    4.0      8.0          0
# 9997        1930            WN        646  ...    4.0      8.0          0
# 9998        1550            WN        656  ...    3.0      6.0          0
# 9999        1210            WN        680  ...    6.0     10.0          0
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df = df.sample(frac = 1)
#reordena la base de datos y mantiene todas las columas

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.DepTime
# Out:
# 3466     754.0
# 862     1110.0
# 2141    1253.0
# 2878    1516.0
# 3049    1702.0
#          ...
# 1806     641.0
# 5208    2110.0
# 7755    1009.0
# 5695    1711.0
# 9054     842.0
# Name: DepTime, Length: 10000, dtype: float64

# %%
df.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df.values
# Out:
# array([[2008, 1, 4, ..., nan, nan, nan],
#        [2008, 1, 3, ..., nan, nan, nan],
#        [2008, 1, 3, ..., 3.0, 0.0, 0.0],
#        ...,
#        [2008, 1, 5, ..., nan, nan, nan],
#        [2008, 1, 4, ..., 1.0, 0.0, 61.0],
#        [2008, 1, 6, ..., nan, nan, nan]], dtype=object)

# %%
df2 = df.head(10)

# %%
df2.head(20)
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 3466  2008      1           4          5    754.0         730   1031.0
# 862   2008      1           3          4   1110.0        1055   1307.0
# 2141  2008      1           3          4   1253.0        1230   1421.0
# 2878  2008      1           4          5   1516.0        1510   1614.0
# 3049  2008      1           4          5   1702.0        1555   1811.0
# 2213  2008      1           3          4      NaN        1805      NaN
# 6473  2008      1           5          6   1658.0        1610   1917.0
# 4632  2008      1           4          5   1932.0        1925   2057.0
# 6436  2008      1           5          6    721.0         720    940.0
# 4036  2008      1           4          5   1055.0        1040   1225.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 3466        1020            WN        550  ...    4.0      6.0          0
# ...
